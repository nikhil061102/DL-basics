# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train = X_train / 255
X_test = X_test / 255
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4675 - accuracy: 0.8770
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3039 - accuracy: 0.9158
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2831 - accuracy: 0.9208
# Epoch 4/5
# 1875/1875 [==============================] - 2s 983us/step - loss: 0.2733 - accuracy: 0.9234
# Epoch 5/5
# 1875/1875 [==============================] - 2s 915us/step - loss: 0.2662 - accuracy: 0.9260

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 0s 935us/step - loss: 0.2697 - accuracy: 0.9257
# [0.26970285177230835, 0.9257000088691711]

# %%
y_pred_prob = model.predict(X_test_flattened)
y_pred = np.argmax(y_pred_prob, axis=1)
for i in range(5):
    plt.matshow(X_test[i])
    print(i+1,". Predicted value: ",y_pred[i], " Actual value: ",y_test[i])
# Out:
# 313/313 [==============================] - 0s 837us/step
# 1 . Predicted value:  7  Actual value:  7
# 2 . Predicted value:  2  Actual value:  2
# 3 . Predicted value:  1  Actual value:  1
# 4 . Predicted value:  0  Actual value:  0
# 5 . Predicted value:  4  Actual value:  4

# %%
cm = tf.math.confusion_matrix(y_test, y_pred)
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('pred')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='leaky_relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2932 - accuracy: 0.9164
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1512 - accuracy: 0.9554
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1095 - accuracy: 0.9676
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0845 - accuracy: 0.9750
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0684 - accuracy: 0.9792

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9731
# [0.0889773890376091, 0.9731000065803528]

# %%
y_pred = model.predict(X_test_flattened)
y_pred_labels = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_labels)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('pred')
plt.ylabel('Truth')
# Out:
# 313/313 [==============================] - 0s 876us/step
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(400, input_shape=(784,), activation='leaky_relu'),
    keras.layers.Dense(100, activation='leaky_relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2178 - accuracy: 0.9344
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1013 - accuracy: 0.9691
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0740 - accuracy: 0.9765
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0603 - accuracy: 0.9813
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0512 - accuracy: 0.9840

# %%
model.evaluate(X_test_flattened,y_test)
y_pred = model.predict(X_test_flattened)
y_pred_labels = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_labels)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('pred')
plt.ylabel('Truth')
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0964 - accuracy: 0.9724
# 313/313 [==============================] - 0s 1ms/step
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(500, activation='leaky_relu'),
    keras.layers.Dense(250, activation='leaky_relu'),
    keras.layers.Dense(100, activation='leaky_relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)

model.evaluate(X_test,y_test)
y_pred = model.predict(X_test)
y_pred_labels = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_labels)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('pred')
plt.ylabel('Truth')
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2093 - accuracy: 0.9366
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1092 - accuracy: 0.9660
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0815 - accuracy: 0.9742
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0695 - accuracy: 0.9786
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0638 - accuracy: 0.9795
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1213 - accuracy: 0.9642
# 313/313 [==============================] - 1s 2ms/step
# Text(95.72222222222221, 0.5, 'Truth')
